# %%
import os
import pandas as pd
from collections import defaultdict
import csv

# %%
from ekonlpy.sentiment import MPCK
mpck = MPCK()

# %%
file_list = os.listdir('data/minutes/txt/')

# %%
NoOfPositiveNgrams, NoOfnegativeNgrams = 0, 0
for file in file_list:
    
    positiveNgram = pd.read_csv('data/res/positive.csv', sep='\n', header=None, names=['positiveNgram'], encoding='utf-8')
    negativeNgram = pd.read_csv('data/res/negative.csv', sep='\n', header=None, names=['negativeNgram'], encoding='utf-8')

#     read minutes file    
    minutes = open('data/minutes/txt/'+file, 'r', encoding='utf-8').read()   
    
#     make ngrams
    minutesTokens = mpck.tokenize(minutes)
    minutesNgrams = mpck.ngramize(minutesTokens)
    
    for mN, pN, nN in zip(minutesNgrams+minutesTokens, positiveNgram.positiveNgram, negativeNgram.negativeNgram):
        if mN == pN:
            NoOfPositiveNgrams = NoOfPositiveNgrams + 1            
            print('Positive match ngrams: ')
            print(mN, '==', pN)
        elif mN == nN:
            NoOfnegativeNgrams = NoOfnegativeNgrams + 1
            print('negative match ngrams: ')
            print(mN, '==', nN)
        
print('최종값 : ')
print('NoOfPositiveNgrams : ', NoOfPositiveNgrams)
print('NoOfnegativeNgrams : ', NoOfnegativeNgrams)

# get polarity score of sentence
polarityScore_sentence = (NoOfPositiveNgrams - NoOfnegativeNgrams)/(NoOfPositiveNgrams + NoOfnegativeNgrams)

# save file
with open('data/res/polarityScore.csv', 'a', encoding='utf-8') as f:
    f.write(file[3:11]+","+str(polarityScore_sentence)+'\n')
# Out:
# negative match ngrams:
# 심화/NNG == 심화/NNG
# Positive match ngrams:
# 영향/NNG == 영향/NNG
# negative match ngrams:
# 하/VV == 하/VV
# Positive match ngrams:
# 제한/NNG == 제한/NNG
# Positive match ngrams:
# 대/VV == 대/VV
# negative match ngrams:
# 경제/NNG;완만/NNG;회복/NNG == 경제/NNG;완만/NNG;회복/NNG
# negative match ngrams:
# 그치/VV == 그치/VV
# negative match ngrams:
# 지지/NNG == 지지/NNG
# Positive match ngrams:
# 영향/NNG == 영향/NNG
# negative match ngrams:
# 되/VV == 되/VV
# Positive match ngrams:
# 결제/NNG == 결제/NNG
# negative match ngrams:
# 안정/NNG == 안정/NNG
# negative match ngrams:
# 추정/NNG == 추정/NNG
# negative match ngrams:
# 국제/NNG;유가/NNG;원자재/NNG;가격/NNG;상승/NNG == 국제/NNG;유가/NNG;원자재/NNG;가격/NNG;상승/NNG
# Positive match ngrams:
# 지수/NNG == 지수/NNG
# negative match ngrams:
# 기업/NNG == 기업/NNG
# Positive match ngrams:
# 차질/NNG == 차질/NNG
# negative match ngrams:
# 변화/NNG == 변화/NNG
# negative match ngrams:
# 되/VV == 되/VV
# negative match ngrams:
# 효과/NNG == 효과/NNG
# negative match ngrams:
# 기대/NNG == 기대/NNG
# Positive match ngrams:
# 트/NNG == 트/NNG
# negative match ngrams:
# 부동산/NNG == 부동산/NNG
# negative match ngrams:
# 해소/NNG == 해소/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 불구/NNG == 불구/NNG
# negative match ngrams:
# 관행/NNG == 관행/NNG
# negative match ngrams:
# 안전자산/NNG == 안전자산/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 높/VA == 높/VA
# negative match ngrams:
# 대해/VV == 대해/VV
# negative match ngrams:
# 대해/VV == 대해/VV
# Positive match ngrams:
# 금리/NNG == 금리/NNG
# Positive match ngrams:
# 하락/NNG == 하락/NNG
# Positive match ngrams:
# 인플레이션/NNG == 인플레이션/NNG
# negative match ngrams:
# 생활/NNG == 생활/NNG
# negative match ngrams:
# 흑자/NNG == 흑자/NNG
# negative match ngrams:
# 중요/NNG == 중요/NNG
# negative match ngrams:
# 대해/VV == 대해/VV
# Positive match ngrams:
# 작용/NNG == 작용/NNG
# Positive match ngrams:
# 채권펀드/NNG == 채권펀드/NNG
# negative match ngrams:
# 기대/NNG == 기대/NNG
# negative match ngrams:
# 세계/NNG == 세계/NNG
# negative match ngrams:
# 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG == 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG
# negative match ngrams:
# 가운데/NNG == 가운데/NNG
# negative match ngrams:
# 평가/NNG == 평가/NNG
# negative match ngrams:
# 않/VX == 않/VX
# negative match ngrams:
# 신흥국/NNG == 신흥국/NNG
# negative match ngrams:
# 보/VV == 보/VV
# Positive match ngrams:
# 필요/NNG == 필요/NNG
# negative match ngrams:
# 완만/NNG == 완만/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 채권/NNG == 채권/NNG
# negative match ngrams:
# 대해/VV == 대해/VV
# Positive match ngrams:
# 대출/NNG == 대출/NNG
# Positive match ngrams:
# 불안/NNG == 불안/NNG
# negative match ngrams:
# 경제/NNG == 경제/NNG
# negative match ngrams:
# 자산/NNG == 자산/NNG
# negative match ngrams:
# 유출입/NNG == 유출입/NNG
# Positive match ngrams:
# 인플레이션/NNG == 인플레이션/NNG
# negative match ngrams:
# 상당기간/NNG == 상당기간/NNG
# Positive match ngrams:
# ecb/NNG == ecb/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# Positive match ngrams:
# 힘입/VV == 힘입/VV
# negative match ngrams:
# 되/XSV == 되/XSV
# negative match ngrams:
# 관/NNG == 관/NNG
# negative match ngrams:
# 내수/NNG == 내수/NNG
# negative match ngrams:
# 원인/NNG == 원인/NNG
# negative match ngrams:
# 문제/NNG == 문제/NNG
# negative match ngrams:
# 아울러/MAG == 아울러/MAG
# Positive match ngrams:
# 상승률/NNG == 상승률/NNG
# negative match ngrams:
# 두/VV == 두/VV
# negative match ngrams:
# 변동성/NNG == 변동성/NNG
# negative match ngrams:
# 함/XSV == 함/XSV
# negative match ngrams:
# 국제/NNG == 국제/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 인하/VV == 인하/VV
# negative match ngrams:
# 실질/NNG == 실질/NNG
# negative match ngrams:
# 보/VV == 보/VV
# Positive match ngrams:
# 나타나/VV == 나타나/VV
# negative match ngrams:
# 되/VV == 되/VV
# negative match ngrams:
# gdp/NNG == gdp/NNG
# negative match ngrams:
# 외화/NNG == 외화/NNG
# negative match ngrams:
# 국채/NNG;금리/NNG;하락/NNG == 국채/NNG;금리/NNG;하락/NNG
# Positive match ngrams:
# 통과/NNG == 통과/NNG
# negative match ngrams:
# 국채/NNG == 국채/NNG
# negative match ngrams:
# 금융시장/NNG == 금융시장/NNG
# negative match ngrams:
# 대해/VV == 대해/VV
# Positive match ngrams:
# 금지/NNG == 금지/NNG
# negative match ngrams:
# 되/XSV == 되/XSV
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 언급/NNG == 언급/NNG
# negative match ngrams:
# 금융시장/NNG == 금융시장/NNG
# negative match ngrams:
# 불확실성/NNG == 불확실성/NNG
# negative match ngrams:
# 상/NNG == 상/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# Positive match ngrams:
# 금융안정/NNG == 금융안정/NNG
# negative match ngrams:
# 금융시장/NNG == 금융시장/NNG
# negative match ngrams:
# 보/VV == 보/VV
# negative match ngrams:
# 개선/NNG == 개선/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 지속/NNG == 지속/NNG
# negative match ngrams:
# 아울러/MAG == 아울러/MAG
# negative match ngrams:
# 경제/NNG == 경제/NNG
# negative match ngrams:
# 따르/VV == 따르/VV
# negative match ngrams:
# 규모/NNG == 규모/NNG
# negative match ngrams:
# 전망/NNG == 전망/NNG
# negative match ngrams:
# 되/VV == 되/VV
# negative match ngrams:
# 수입/NNG == 수입/NNG
# negative match ngrams:
# 되/VV == 되/VV
# negative match ngrams:
# 면밀/NNG == 면밀/NNG
# negative match ngrams:
# 경제/NNG == 경제/NNG
# negative match ngrams:
# 효과/NNG == 효과/NNG
# negative match ngrams:
# 국채/NNG == 국채/NNG
# negative match ngrams:
# fed/NNG == fed/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# Positive match ngrams:
# 목적/NNG == 목적/NNG
# negative match ngrams:
# 인하/VV == 인하/VV
# negative match ngrams:
# 수준/NNG == 수준/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 강화/NNG == 강화/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 되/XSV == 되/XSV
# Positive match ngrams:
# 인상/NNG == 인상/NNG
# negative match ngrams:
# 보/VV == 보/VV
# negative match ngrams:
# 있/VA == 있/VA
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 확대/NNG == 확대/NNG
# negative match ngrams:
# 되/XSV == 되/XSV
# negative match ngrams:
# 크/VA == 크/VA
# negative match ngrams:
# 은행/NNG == 은행/NNG
# negative match ngrams:
# 기대/NNG == 기대/NNG
# negative match ngrams:
# 성장/NNG == 성장/NNG
# Positive match ngrams:
# 유출/NNG == 유출/NNG
# negative match ngrams:
# 되/VV == 되/VV
# negative match ngrams:
# 높/VA == 높/VA
# negative match ngrams:
# 물량/NNG == 물량/NNG
# Positive match ngrams:
# 견해/NNG == 견해/NNG
# negative match ngrams:
# 확대/NNG == 확대/NNG
# Positive match ngrams:
# 영향/NNG == 영향/NNG
# Positive match ngrams:
# 금리/NNG == 금리/NNG
# negative match ngrams:
# 기조/NNG == 기조/NNG
# negative match ngrams:
# 크/VA == 크/VA
# Positive match ngrams:
# 지역/NNG == 지역/NNG
# negative match ngrams:
# 경제/NNG == 경제/NNG
# negative match ngrams:
# 속도/NNG == 속도/NNG
# negative match ngrams:
# 축소/NNG == 축소/NNG
# negative match ngrams:
# 정책공/NNG == 정책공/NNG
# negative match ngrams:
# 조/NNG == 조/NNG
# Positive match ngrams:
# 예정/NNG == 예정/NNG
# Positive match ngrams:
# 제도/NNG == 제도/NNG
# negative match ngrams:
# 중심/NNG == 중심/NNG
# negative match ngrams:
# 약화/NNG == 약화/NNG
# negative match ngrams:
# 있/VA == 있/VA
# negative match ngrams:
# 위험/NNG == 위험/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 되/XSV == 되/XSV
# negative match ngrams:
# 우려/NNG == 우려/NNG
# negative match ngrams:
# 국채/NNG == 국채/NNG
# negative match ngrams:
# 대해/VV == 대해/VV
# negative match ngrams:
# 전망/NNG == 전망/NNG
# negative match ngrams:
# 글로벌/NNG == 글로벌/NNG
# negative match ngrams:
# 확대/NNG == 확대/NNG
# negative match ngrams:
# 축소/NNG == 축소/NNG
# negative match ngrams:
# 악화/NNG == 악화/NNG
# negative match ngrams:
# 위험/NNG == 위험/NNG
# negative match ngrams:
# 증가/NNG == 증가/NNG
# negative match ngrams:
# 회복/NNG == 회복/NNG
# negative match ngrams:
# 과도/NNG == 과도/NNG
# Positive match ngrams:
# 유가/NNG == 유가/NNG
# negative match ngrams:
# 관계/NNG == 관계/NNG
# Positive match ngrams:
# 금리/NNG == 금리/NNG
# negative match ngrams:
# 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG == 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG
# negative match ngrams:
# 가운데/NNG == 가운데/NNG
# negative match ngrams:
# 위기/NNG == 위기/NNG
# Positive match ngrams:
# 조치/NNG == 조치/NNG
# negative match ngrams:
# 갭/NNG == 갭/NNG
# Positive match ngrams:
# 낮/VA == 낮/VA
# negative match ngrams:
# 지적/NNG == 지적/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 글로벌/NNG == 글로벌/NNG
# negative match ngrams:
# 어렵/VA == 어렵/VA
# Positive match ngrams:
# 가능성/NNG == 가능성/NNG
# negative match ngrams:
# 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG == 국제/NNG;금융시장/NNG;변동성/NNG;확대/NNG
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 있/VV == 있/VV
# negative match ngrams:
# 주력/NNG == 주력/NNG
# negative match ngrams:
# 통화정책/NNG == 통화정책/NNG
# negative match ngrams:
# 하/VV == 하/VV
# negative match ngrams:
# 있/VV == 있/VV
# Positive match ngrams:
# 돌아/VV == 돌아/VV
# negative match ngrams:
# 외국인/NNG == 외국인/NNG
# negative match ngrams:
# 더불/VV == 더불/VV
# negative match ngrams:
# 같/VA == 같/VA
# Positive match ngrams:
# 주택/NNG == 주택/NNG
# negative match ngrams:
# 점/NNG == 점/NNG
# negative match ngrams:
# 역할/NNG == 역할/NNG
# negative match ngrams:
# 대체/NNG == 대체/NNG
# Positive match ngrams:
# 상승/NNG == 상승/NNG
# negative match ngrams:
# 전망/NNG == 전망/NNG
# negative match ngrams:
# 갭/NNG == 갭/NNG
# Positive match ngrams:
# 원칙/NNG == 원칙/NNG
# negative match ngrams:
# 투자/NNG == 투자/NNG
# negative match ngrams:
# 차입/NNG == 차입/NNG
# negative match ngrams:
# 되/XSV == 되/XSV
# negative match ngrams:
# 하/XSV == 하/XSV
# negative match ngrams:
# 때/NNG == 때/NNG
# Positive match ngrams:
# 인플레이션/NNG == 인플레이션/NNG
# negative match ngrams:
# 갈등/NNG == 갈등/NNG
# 최종값 :
# NoOfPositiveNgrams :  43
# NoOfnegativeNgrams :  166
